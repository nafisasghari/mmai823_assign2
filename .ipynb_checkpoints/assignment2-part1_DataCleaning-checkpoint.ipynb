# %%
#import packages
# %matplotlib inline

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

from sklearn.model_selection import train_test_split

#from sklearn.base import BaseEstimator, TransformerMixin
#from category_encoders.target_encoder import TargetEncoder
#from category_encoders.one_hot import OneHotEncoder

#from sklearn.pipeline import Pipeline
#from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import StandardScaler
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.impute import SimpleImputer 

from sklearn.feature_selection import SelectKBest , chi2, f_classif

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix , classification_report, roc_auc_score, f1_score, accuracy_score
from sklearn import tree

from sklearn.ensemble import RandomForestClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC


#from mlxtend.classifier import StackingClassifier

# %%
df = pd.read_excel("data/Bankruptcy_data_Final.xlsx")
df.head()
# Out:
#    Data Year - Fiscal  Tobin's Q   EPS  Liquidity  Profitability  \
# 0                1979       0.98  1.58       0.36           0.18
# 1                1980       0.98  1.41       0.36           0.19
# 2                1981       0.87  0.31       0.32           0.13
# 3                1982       1.13  0.71       0.28           0.14
# 4                1983       1.26  0.75       0.41           0.13
#
#    Productivity  Leverage Ratio  Asset Turnover  Operational Margin  \
# 0          0.13            1.33            1.77                0.07
# 1          0.12            1.31            1.59                0.07
# 2          0.08            1.03            1.55                0.05
# 3          0.08            0.80            1.39                0.06
# 4          0.08            0.20            1.30                0.06
#
#    Return on Equity  Market Book Ratio  Assets Growth  Sales Growth  \
# 0              0.15               2.22            NaN           NaN
# ...

# %%
data = df.copy()

# %%
df.describe().transpose()
# Out:
#                       count         mean           std           min  \
# Data Year - Fiscal  92872.0  2004.105888      9.875926  1.979000e+03
# Tobin's Q           92620.0    25.369008    902.818813  9.283364e-03
# EPS                 92867.0   -14.461355   2195.467288 -3.840000e+05
# Liquidity           92625.0    -2.631237    121.610921 -2.596852e+04
# Profitability       92625.0   -29.537274    677.230667 -7.968200e+04
# Productivity        92625.0    -1.222870     35.885556 -5.093000e+03
# Leverage Ratio      92846.0     1.345316    253.038093 -7.811000e+03
# Asset Turnover      92625.0     1.053613      2.115945 -3.159000e+01
# Operational Margin  87315.0    -7.915485    214.460079 -3.017570e+04
# Return on Equity    92864.0    -2.112382    352.596902 -8.887514e+04
# Market Book Ratio   92815.0   358.506265  26063.637981 -3.151500e+06
# Assets Growth       86171.0     1.294075     73.769522 -1.000000e+00
# Sales Growth        86171.0     1.900108    177.632638 -2.743103e+01
# ...

# %%
# Check missing value
df.isnull().sum()
# Out:
# Data Year - Fiscal       0
# Tobin's Q              252
# EPS                      5
# Liquidity              247
# Profitability          247
# Productivity           247
# Leverage Ratio          26
# Asset Turnover         247
# Operational Margin    5557
# Return on Equity         8
# Market Book Ratio       57
# Assets Growth         6701
# Sales Growth          6701
# Employee Growth       7010
# BK                       0
# dtype: int64

# %%
df.shape
# Out:
# (92872, 15)

# %%
df.columns
# Out:
# Index(['Data Year - Fiscal', 'Tobin's Q', 'EPS', 'Liquidity', 'Profitability',
#        'Productivity', 'Leverage Ratio', 'Asset Turnover',
#        'Operational Margin', 'Return on Equity', 'Market Book Ratio',
#        'Assets Growth', 'Sales Growth', 'Employee Growth', 'BK'],
#       dtype='object')

# %%
import pandas_profiling
pandas_profiling.ProfileReport(df)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
df.isnull().sum()
# Out:
# Data_Year_-_Fiscal       0
# Tobin's_Q              252
# EPS                      5
# Liquidity              247
# Profitability          247
# Productivity           247
# Leverage_Ratio          26
# Asset_Turnover         247
# Operational_Margin    5557
# Return_on_Equity         8
# Market_Book_Ratio       57
# Assets_Growth         6701
# Sales_Growth          6701
# Employee_Growth       7010
# BK                       0
# dtype: int64

# %%
df[(df["Operational Margin"].isna())].head(10)
# Out:
#      Data Year - Fiscal  Tobin's Q   EPS  Liquidity  Profitability  \
# 81                 1987       2.45 -0.07       0.00          -1.35
# 82                 1988       2.07 -0.02       0.08          -1.10
# 83                 1989       1.59 -0.04      -0.30          -0.66
# 84                 1990      46.57 -0.16      -5.35         -22.17
# 85                 1991       2.55 -0.01      -0.16          -0.58
# 86                 1992      88.40 -0.02      -6.95         -22.80
# 229                2011      44.52 -0.02     -11.32        -102.03
# 230                2012      82.23 -0.02     -13.90        -126.31
# 231                2013      55.83 -0.04     -12.22        -104.15
# 232                2014     666.98 -0.01    -164.43       -1289.64
#
#      Productivity  Leverage Ratio  Asset Turnover  Operational Margin  \
# 81          -0.06            0.89             0.0                 NaN
# 82          -0.05            1.53             0.0                 NaN
# ...

# %%
# target(Loyalty) distribution
df["BK"].value_counts()
# Out:
# 0    92314
# 1      558
# Name: BK, dtype: int64

# %%
558/(558+92314)*100
# Out:
# 0.600826944611939

# %%
df = data.copy()

# %%
#Drop rows with more than 5 missing values
df = df[df.isnull().sum(axis=1) < 3]

# %%
# Check missing value
df.isnull().sum()
# Out:
# Data Year - Fiscal       0
# Tobin's Q                1
# EPS                      0
# Liquidity                0
# Profitability            0
# Productivity             0
# Leverage Ratio           8
# Asset Turnover           0
# Operational Margin    4463
# Return on Equity         3
# Market Book Ratio       25
# Assets Growth            0
# Sales Growth             0
# Employee Growth        304
# BK                       0
# dtype: int64

# %%
df = df.fillna(0)

# %%
#(92872, 15)
print(df.shape)
df["BK"].value_counts()
# Out:
# (85972, 15)
# 0    85418
# 1      554
# Name: BK, dtype: int64

# %% [markdown]
# The input and output variables are described below:
# EPS – Earnings Per Share
#
# Liquidity – Working Capital/Total Assets
#
# Profitability – Retained Earnings/Total Assets
# Productivity – EBIT/Total Assets
# Leverage Ratio – (Total Long-term debt + Debt in Current liabilities)/Stockholders Equity
# Asset Turnover – Sales/ Total Assets
# Operational Margin – EBIT/Sales
# Market Book Ratio – (Price Close Annual Fiscal * Common Shares Outstanding)/Book Value Per Share
# Asset Growth – Change in assets from previous year
# Sales Growth – Change in sales from previous year
# Employee Growth – Change in employees from previous year
# Tobin’s Q – (Total market value of company + liabilities)/ (Total asset or book value + liabilities)
# BK – Company bankrupt or not

# %%
df[df.BK == 1].isnull().sum()
# Out:
# Data Year - Fiscal     0
# Tobin's Q              0
# EPS                    0
# Liquidity              0
# Profitability          0
# Productivity           0
# Leverage Ratio         0
# Asset Turnover         0
# Operational Margin    17
# Return on Equity       0
# Market Book Ratio      5
# Assets Growth          0
# Sales Growth           0
# Employee Growth       68
# BK                     0
# dtype: int64

# %%
corr_matrix = df.corr()
corr_matrix["BK"].sort_values(ascending=False)
# Out:
# BK                    1.000000
# Asset Turnover        0.014968
# Profitability         0.002576
# Operational Margin    0.001578
# Productivity          0.001266
# Liquidity             0.001236
# Employee Growth       0.001142
# Leverage Ratio       -0.000169
# Sales Growth         -0.000183
# Assets Growth        -0.001397
# Market Book Ratio    -0.001528
# Tobin's Q            -0.001731
# Return on Equity     -0.006505
# EPS                  -0.007188
# Data Year - Fiscal   -0.090539
# Name: BK, dtype: float64

# %%
sns.set(style="white")

corr_matrix = df.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_matrix, mask=mask, cmap=cmap, vmax=.6, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot = True, fmt=".0")
plt.show()

# %%
df.hist(figsize = (13,13), bins = 50)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, PowerTransformer

num_features_1 = [col for col in df.columns if col != 'BK']

scaler = StandardScaler()
df[num_features_1] = scaler.fit_transform(df[num_features_1])
#X_test[num_features_1] = scaler.transform(X_test[num_features_1])

# %%
df.hist(figsize = (13,13), bins = 50)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, PowerTransformer
num_features_2 = [col for col in df.columns if col != 'BK']

scaler_pt = PowerTransformer(method='yeo-johnson')
df[num_features_2] = scaler_pt.fit_transform(df[num_features_2])
#X_test[num_features_2] = scaler_pt.transform(X_test[num_features_2])

# %%
df.hist(figsize = (13,13), bins = 50)
plt.show()

# %%
df.drop('Data Year - Fiscal' , axis = 1 , inplace = True)

# %%
#keep 20% for the very last model testing

#from sklearn.model_selection import train_test_split
train , test = train_test_split(df, random_state = 42 , test_size = 0.2 , stratify = df['BK'])

# %%
train["BK"].value_counts() , test["BK"].value_counts()
# Out:
# (0    68334
#  1      443
#  Name: BK, dtype: int64, 0    17084
#  1      111
#  Name: BK, dtype: int64)

# %%
target = "BK"
features = list(train.columns)

features = [f for f in features if f!=target]

X_train = train[features].reset_index(drop=True)
y_train = train[[target]].reset_index(drop=True)


X_test = test[features].reset_index(drop=True)
y_test = test[[target]].reset_index(drop=True)

# %%
def GridSearch_func(X,y, estimator, param_grid, cv=10 , scoring = 'roc_auc'):

    grid_search = GridSearchCV(estimator, param_grid, cv=cv,
                           scoring=scoring)
    grid_search.fit(X, y)
    print ("best parameters: ", grid_search.best_params_)
    #print(f"best {scoring} score during training: ", grid_search.best_score_)
    print("-------"*10)
    means = grid_search.cv_results_['mean_test_score']
    stds = grid_search.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, grid_search.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    print(f"mean of {scoring} scores during validation: {sum(means)/len(means):0.3f}")
    print("-------"*10)
    best_model = grid_search.best_estimator_
    print ("best_model: ", best_model)
    
    return best_model

# %%
def metrics( clf, X_test = X_test , y_test = y_test):
    
    y_pred = clf.predict(X_test)

    cm = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:")
    print()
    print(cm)
    print("-----"*5)
    
    print(classification_report(y_test, y_pred))
    print("-----"*5)
    
    y_proba = clf.predict_proba(X_test)
    y_scores = y_proba[:, 1]
    auc = roc_auc_score (y_test, y_scores)
    
    print(f"ROC AUC score: {auc:.4f}")
    print()
    
    f1 = f1_score(y_test, y_pred)
    print(f"f1 score: {f1:.4f}")

# %%
#Random Forest with Final features
rf_clf = RandomForestClassifier(n_jobs = -1, random_state=42 , class_weight= {0:0.01, 1:0.99} ) #class_weight= {0:0.75, 1:0.25}
param_grid_rf = [{'n_estimators': [ 50]  , 'max_depth' : [ 10] }]

rf_model = GridSearch_func(X = X_train, y= np.ravel(y_train),
                           estimator = rf_clf, param_grid = param_grid_rf, cv=4  , scoring = "roc_auc")
# Out:
# best parameters:  {'max_depth': 10, 'n_estimators': 50}
# ----------------------------------------------------------------------
# 0.912 (+/-0.046) for {'max_depth': 10, 'n_estimators': 50}
#
# mean of roc_auc scores during validation: 0.912
# ----------------------------------------------------------------------
# best_model:  RandomForestClassifier(bootstrap=True, class_weight={0: 0.01, 1: 0.99},
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=50, n_jobs=-1, oob_score=False,
#                        random_state=42, verbose=0, warm_start=False)

# %%
print("Random Forest Classifier" )
print()
metrics(rf_model, X_test= X_test)
# Out:
# Random Forest Classifier
#
# Confusion Matrix:
#
# [[16585   499]
#  [   60    51]]
# -------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     17084
#            1       0.09      0.46      0.15       111
#
#     accuracy                           0.97     17195
#    macro avg       0.54      0.72      0.57     17195
# weighted avg       0.99      0.97      0.98     17195
#
# -------------------------
# ROC AUC score: 0.9163
#
# f1 score: 0.1543

# %%
importances = rf_model.feature_importances_
std = np.std([tree.feature_importances_ for tree in rf_model.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

imp_df = pd.DataFrame({"Feature": X_train.columns[indices] , "importance" : importances[indices]})
print(imp_df)
                       
# Plot the feature importances of the forest - top 10
n = min(10,len(X_train.columns))
plt.figure(figsize=(20,5))

plt.title("Feature importances")
plt.bar(range(n), importances[indices][:n],
       color="purple", yerr=std[indices][:n], align="center")
plt.xticks(range(n), X_train.columns[indices])

plt.xlim([-1, n])
plt.show()
# Out:
# Feature ranking:
#                Feature  importance
# 0     Return on Equity    0.191579
# 1                  EPS    0.099099
# 2   Operational Margin    0.099005
# 3    Market Book Ratio    0.092591
# 4        Profitability    0.083043
# 5         Productivity    0.078835
# 6            Liquidity    0.073749
# 7       Leverage Ratio    0.072641
# 8        Assets Growth    0.057175
# 9       Asset Turnover    0.047392
# 10        Sales Growth    0.038322
# 11           Tobin's Q    0.036144
# 12     Employee Growth    0.030426

# %%
#Logistic Regression
lg_clf = LogisticRegression(n_jobs = -1 , class_weight= {0:0.01, 1:0.99} )
param_grid_lg = [{"penalty" :['l1', 'l2'] , "C" :[ 0.1, 1 ]}]
lg_model = GridSearch_func(X = X_train, y= np.ravel(y_train),
                           estimator = lg_clf, param_grid = param_grid_lg, cv= 5  , scoring = "roc_auc" )
# Out:
# C:\Users\Nafiseh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Nafiseh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1544: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 4.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# C:\Users\Nafiseh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Nafiseh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1544: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 4.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# ...

# %%
print("Logistic Regression Classifier" )
print()
log_reg_metrics = metrics(lg_model, X_test)
# Out:
# Logistic Regression Classifier
#
# Confusion Matrix:
#
# [[15607  1477]
#  [   55    56]]
# -------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     17084
#            1       0.04      0.50      0.07       111
#
#     accuracy                           0.91     17195
#    macro avg       0.52      0.71      0.51     17195
# weighted avg       0.99      0.91      0.95     17195
#
# -------------------------
# ROC AUC score: 0.7697
#
# f1 score: 0.0681
